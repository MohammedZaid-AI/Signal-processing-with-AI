# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
path="D:\\Zaids Work\\Signal processing with AI\\new data\\heart_attack_prediction_dataset.csv"
df=pd.read_csv(path)
df
# Out:
#      Patient ID  Age     Sex  Cholesterol Blood Pressure  Heart Rate  \
# 0       BMW7812   67    Male          208         158/88          72
# 1       CZE1114   21    Male          389         165/93          98
# 2       BNI9906   21  Female          324         174/99          72
# 3       JLN3497   84    Male          383        163/100          73
# 4       GFO8847   66    Male          318          91/88          93
# ...         ...  ...     ...          ...            ...         ...
# 8758    MSV9918   60    Male          121          94/76          61
# 8759    QSV6764   28  Female          120        157/102          73
# 8760    XKA5925   47    Male          250         161/75         105
# 8761    EPE6801   36    Male          178         119/67          60
# 8762    ZWN9666   25  Female          356         138/67          75
#
#       Diabetes  Family History  Smoking  Obesity  ...  \
# 0            0               0        1        0  ...
# ...

# %%
df.shape
# Out:
# (8763, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8763 entries, 0 to 8762
# Data columns (total 26 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Patient ID                       8763 non-null   object
#  1   Age                              8763 non-null   int64
#  2   Sex                              8763 non-null   object
#  3   Cholesterol                      8763 non-null   int64
#  4   Blood Pressure                   8763 non-null   object
#  5   Heart Rate                       8763 non-null   int64
#  6   Diabetes                         8763 non-null   int64
#  7   Family History                   8763 non-null   int64
#  8   Smoking                          8763 non-null   int64
#  9   Obesity                          8763 non-null   int64
#  10  Alcohol Consumption              8763 non-null   int64
#  11  Exercise Hours Per Week          8763 non-null   float64
# ...

# %%
df.describe()
# Out:
#                Age  Cholesterol   Heart Rate     Diabetes  Family History  \
# count  8763.000000  8763.000000  8763.000000  8763.000000     8763.000000
# mean     53.707977   259.877211    75.021682     0.652288        0.492982
# std      21.249509    80.863276    20.550948     0.476271        0.499979
# min      18.000000   120.000000    40.000000     0.000000        0.000000
# 25%      35.000000   192.000000    57.000000     0.000000        0.000000
# 50%      54.000000   259.000000    75.000000     1.000000        0.000000
# 75%      72.000000   330.000000    93.000000     1.000000        1.000000
# max      90.000000   400.000000   110.000000     1.000000        1.000000
#
#            Smoking      Obesity  Alcohol Consumption  Exercise Hours Per Week  \
# count  8763.000000  8763.000000          8763.000000              8763.000000
# mean      0.896839     0.501426             0.598083                10.014284
# ...

# %%
plt.hist(df.Age)
plt.title("Age distribution")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# #other visualize
# #bar pie etc
# #check for outliers, box plot
# #countplot to check cat data distribution

# %%
#distribution of heart attack
df.iloc[:,-1].value_counts()
# Out:
# Heart Attack Risk
# 0    5624
# 1    3139
# Name: count, dtype: int64

# %%
import seaborn as sns
sns.countplot(x='Heart Attack Risk',data=df)
plt.title("Heart Attack Distribution")
plt.xlabel("Heart Attack")
plt.ylabel("Count")
plt.show()

# %%
# split data into input and target
x=df.drop(["Heart Attack Risk"],axis=1)
y=df.iloc[:,-3:-2]
#split the input data into numeric and categorical
df_num=x.select_dtypes(include=np.number)
df_cat=x.select_dtypes(exclude=np.number)
df_num

df_cat=df_cat.loc[:,["Sex","Diet","Country","Continent","Hemisphere"]]
df_cat.describe()
# Out:
#          Sex     Diet  Country Continent           Hemisphere
# count   8763     8763     8763      8763                 8763
# unique     2        3       20         6                    2
# top     Male  Healthy  Germany      Asia  Northern Hemisphere
# freq    6111     2960      477      2543                 5660

# %%
from dataclasses import dataclass

#apply one hot encoding to categorical data
df_cat_en=pd.get_dummies(df_cat,drop_first=True,dtype=int)
df_cat_en
# Out:
#       Sex_Male  Diet_Healthy  Diet_Unhealthy  Country_Australia  \
# 0            1             0               0                  0
# 1            1             0               1                  0
# 2            0             1               0                  0
# 3            1             0               0                  0
# 4            1             0               1                  0
# ...        ...           ...             ...                ...
# 8758         1             1               0                  0
# 8759         0             1               0                  0
# 8760         1             0               0                  0
# 8761         1             0               1                  0
# 8762         0             1               0                  0
#
#       Country_Brazil  Country_Canada  Country_China  Country_Colombia  \
# 0                  0               0              0                 0
# ...

# %%
#standardize the numeric data
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
df_num.iloc[:,[0,1,2,8,11,12,13,14,15,16,17,18,19]]=ss.fit_transform(df_num.iloc[:,[0,1,2,8,11,12,13,14,15,16,17,18,19]])
df_num
# Out:
# C:\Users\MOHAMMED ZAID\AppData\Local\Temp\ipykernel_21724\3117742843.py:6: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 0.62555713 -1.53932232 -1.53932232 ... -0.3156948  -0.83338337
#  -1.35107193]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_num.iloc[:,[0,1,2,8,11,12,13,14,15,16,17,18,19]]=ss.fit_transform(df_num.iloc[:,[0,1,2,8,11,12,13,14,15,16,17,18,19]])
# C:\Users\MOHAMMED ZAID\AppData\Local\Temp\ipykernel_21724\3117742843.py:6: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.64157889  1.59689495  0.79302313 ... -0.12215402 -1.01259666
#   1.18877541]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_num.iloc[:,[0,1,2,8,11,12,13,14,15,16,17,18,19]]=ss.fit_transform(df_num.iloc[:,[0,1,2,8,11,12,13,14,15,16,17,18,19]])
# ...

# %%
#combine both cat and numerical data
x_cleaned=pd.concat([df_num,df_cat_en],axis=1)
x_cleaned
# Out:
#            Age  Cholesterol  Heart Rate  Diabetes  Family History  Smoking  \
# 0     0.625557    -0.641579   -0.147042         0               0        1
# 1    -1.539322     1.596895    1.118179         1               1        1
# 2    -1.539322     0.793023   -0.147042         1               0        0
# 3     1.425621     1.522691   -0.098380         1               1        1
# 4     0.578495     0.718820    0.874867         1               1        1
# ...        ...          ...         ...       ...             ...      ...
# 8758  0.296119    -1.717530   -0.682328         1               1        1
# 8759 -1.209884    -1.729898   -0.098380         1               0        0
# 8760 -0.315695    -0.122154    1.458815         0               1        1
# 8761 -0.833383    -1.012597   -0.730990         1               0        1
# 8762 -1.351072     1.188775   -0.001055         1               1        0
#
#       Obesity  Alcohol Consumption  Exercise Hours Per Week  \
# ...

# %%
# !pip install imbalanced-Learn

# %%
#SMOTE
from imblearn.over_sampling import SMOTE
x_cleaned,y=SMOTE().fit_resample(xtrain,ytrain)

# %%
#traim test split data
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x_cleaned,y,test_size=0.2,random_state=0)
xtrain.shape,xtest.shape,ytrain.shape,ytest.shape

xtest
# Out:
#            Age  Cholesterol  Heart Rate  Diabetes  Family History  Smoking  \
# 23   -1.162822    -1.000229    1.556140         1               1        0
# 325   1.190308    -1.185738    0.290919         0               0        1
# 1916  1.472684    -0.480805    0.777542         1               0        1
# 8483  0.150492    -1.556118    0.951931         1               1        1
# 2631  1.096183     1.423753    1.653464         1               1        1
# ...        ...          ...         ...       ...             ...      ...
# 983   0.154931     0.805390   -0.244367         1               1        1
# 2090  1.096183    -0.431335    1.458815         0               0        1
# 2402 -1.586385    -0.926026    1.215503         1               0        0
# 1425 -0.786321     0.211762    0.096270         1               1        0
# 6107 -1.021634     0.063355    0.826205         1               1        0
#
#       Obesity  Alcohol Consumption  Exercise Hours Per Week  \
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
KNN=KNeighborsClassifier(n_neighbors=5,p=2)
KNN.fit(xtrain,ytrain)
# Out:
# c:\Users\MOHAMMED ZAID\anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py:239: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier()

# %%
ypredict=KNN.predict(xtest)
ypredict
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(ytest,ypredict)
cm
from sklearn.metrics import accuracy_score
acc=accuracy_score(ytest,ypredict)
acc
# Out:
# 0.6069844789356984

# %%
from sklearn.tree import DecisionTreeClassifier
DTC=DecisionTreeClassifier(criterion='entropy',random_state=0)
DTC.fit(xtrain,ytrain)

Ypredict=DTC.predict(xtest)
cm=confusion_matrix(ytest,Ypredict)
cm
acc=accuracy_score(ytest,Ypredict)
acc
# Out:
# 0.593680709534368

# %%
df[['Systolic','diastolic']] = df['Blood Pressure'].str.split('/',expand=True)
df.head()

# Convert 'Systolic','diastolic' these two columns into numeric
df['Systolic'] = pd.to_numeric(df['Systolic'])
df['diastolic'] = pd.to_numeric(df['diastolic'])
df.head()
# Out:
#   Patient ID  Age     Sex  Cholesterol Blood Pressure  Heart Rate  Diabetes  \
# 0    BMW7812   67    Male          208         158/88          72         0
# 1    CZE1114   21    Male          389         165/93          98         1
# 2    BNI9906   21  Female          324         174/99          72         1
# 3    JLN3497   84    Male          383        163/100          73         1
# 4    GFO8847   66    Male          318          91/88          93         1
#
#    Family History  Smoking  Obesity  ...        BMI  Triglycerides  \
# 0               0        1        0  ...  31.251233            286
# 1               1        1        1  ...  27.194973            235
# 2               0        0        0  ...  28.176571            587
# 3               1        1        0  ...  36.464704            378
# 4               1        1        1  ...  21.809144            231
#
#   Physical Activity Days Per Week  Sleep Hours Per Day    Country  \
# ...

# %%
#split the data into input and target
x=df.drop("Heart Attack Risk",axis=1)
y=df.iloc[:,-3:]
y
# Out:
#       Heart Attack Risk  Systolic  diastolic
# 0                     0       158         88
# 1                     0       165         93
# 2                     0       174         99
# 3                     0       163        100
# 4                     0        91         88
# ...                 ...       ...        ...
# 8758                  0        94         76
# 8759                  0       157        102
# 8760                  1       161         75
# 8761                  0       119         67
# 8762                  1       138         67
#
# [8763 rows x 3 columns]

# %% [markdown]
# ## RANDOM FOREST CLASSIFIER

# %%
from sklearn.ensemble import RandomForestClassifier
RFC=RandomForestClassifier(n_estimators=100,criterion="entropy",random_state=0)

RFC.fit(xtrain,ytrain)
ypredict=RFC.predict(xtest)

cm=confusion_matrix(ytest,ypredict)
acc=accuracy_score(ytest,ypredict)
final_acc=acc*100
print(f"Accuracy: {final_acc:.2f} %")
# Out:
# c:\Users\MOHAMMED ZAID\anaconda3\Lib\site-packages\sklearn\base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Accuracy: 70.23 %

# %% [markdown]
# ## HYPER PARAMETER TUNING

# %%
from sklearn.model_selection import GridSearchCV
from warnings import filterwarnings
filterwarnings("ignore")
Parameters={"n_estimators":[100,200,300],
            "criterion":["gini","entropy"],
            "max_depth":[4,6,8,10]
            }
Estimator=RandomForestClassifier(random_state=0)
RFC_grid=GridSearchCV(Estimator,Parameters,scoring="accuracy")
RFC_grid.fit(xtrain,ytrain)

ypredict=RFC_grid.predict(xtest)
cm=confusion_matrix(ytest,ypredict)
acc=accuracy_score(ytest,ypredict)
final_acc=acc*100
print(f"Accuracy: {final_acc:.2f} %")
# Out:
# c:\Users\MOHAMMED ZAID\anaconda3\Lib\site-packages\sklearn\base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\MOHAMMED ZAID\anaconda3\Lib\site-packages\sklearn\base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\MOHAMMED ZAID\anaconda3\Lib\site-packages\sklearn\base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# ...

# %% [markdown]
# # handling imbalanced data

# %% [markdown]
# # smote
# - synthetic minority oversampling technique
# -it is a technique which helps to balance the class distribution by oversampling the minority class
